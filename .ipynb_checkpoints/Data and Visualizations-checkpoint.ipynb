# %% [markdown]
# ### Hi, below is just a quick walkthrough of various tables, quick and easy data manipulation and visualizations done all in python, some data is loaded from free to use .csv files and some data is made of random number generation using NumPy. The first part is mostly data manipulation and extracting useful metrics - while the second part is showing quick examples of visualization using various python libraries. There are obviously many more type of visualizations so if you are looking for a specific chart type let me know.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.drop(['state', 'area code', 'phone number'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    account length international plan voice mail plan  number vmail messages  \
# 0             128                 no             yes                     25
# 1             107                 no             yes                     26
# 2             137                 no              no                      0
# 3              84                yes              no                      0
# 4              75                yes              no                      0
#
#    total day minutes  total day calls  total day charge  total eve minutes  \
# 0              265.1              110             45.07              197.4
# 1              161.6              123             27.47              195.5
# 2              243.4              114             41.38              121.2
# 3              299.4               71             50.90               61.9
# 4              166.7              113             28.34              148.3
#
# ...

# %%
X = df['international plan'].value_counts()
print(X)
# Out:
# no     3010
# yes     323
# Name: international plan, dtype: int64

# %%
df['international plan'].value_counts()[:20].plot(kind='barh')

# %%
df['customer service calls'].value_counts().plot(kind='bar')

# %%
df.describe().transpose()
# Out:
#                          count        mean        std    min     25%     50%  \
# account length          3333.0  101.064806  39.822106   1.00   74.00  101.00
# number vmail messages   3333.0    8.099010  13.688365   0.00    0.00    0.00
# total day minutes       3333.0  179.775098  54.467389   0.00  143.70  179.40
# total day calls         3333.0  100.435644  20.069084   0.00   87.00  101.00
# total day charge        3333.0   30.562307   9.259435   0.00   24.43   30.50
# total eve minutes       3333.0  200.980348  50.713844   0.00  166.60  201.40
# total eve calls         3333.0  100.114311  19.922625   0.00   87.00  100.00
# total eve charge        3333.0   17.083540   4.310668   0.00   14.16   17.12
# total night minutes     3333.0  200.872037  50.573847  23.20  167.00  201.20
# total night calls       3333.0  100.107711  19.568609  33.00   87.00  100.00
# total night charge      3333.0    9.039325   2.275873   1.04    7.52    9.05
# ...

# %%
# Random Data Generation
np.random.seed(0)
n, p = 40, 8
d = np.random.normal(0, 2, (n, p))
d += np.log(np.arange(1, p + 1)) * -5 + 10


# plot
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.violinplot(data=d, inner="points", ax=ax)    
sns.despine()

# %%
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101), 
                 'z': (np.random.randn(100)*15+range(1,101))*2 })
 
# Creating a 2x2 subplot of various data makrers - with a real dataset these 
#suplots could represent any number of variables
plt.subplot(221)
plt.plot( 'x', 'y', data=df, marker='o', alpha=0.4)
plt.subplot(222)
plt.plot( 'x','z', data=df, linestyle='none', marker='o', color="orange", alpha=0.3)
plt.subplot(223)
plt.plot( 'x','z', data=df, linestyle='none', marker='D', color="cyan", alpha=0.3)
plt.subplot(224)
plt.plot( 'x','z', data=df, marker='x', color="grey", alpha=0.3)
plt.show()

# %%
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101), 
                 'z': (np.random.randn(100)*15+range(1,101))*2 })
 
# Creating a subplot with 3x3 graphs. 
plt.subplot(331)
plt.plot( 'x', 'y', data=df, marker='o', alpha=0.4)
plt.subplot(332)
plt.plot( 'x','z', data=df, linestyle='none', marker='o', color="orange", alpha=0.3)
plt.subplot(333)
plt.plot( 'x','z', data=df, linestyle='none', marker='D', color="cyan", alpha=0.3)
plt.subplot(334)
plt.plot( 'x','z', data=df, marker='x', color="grey", alpha=0.3)
plt.subplot(335)
plt.plot( 'x', 'y', data=df, marker='o', alpha=0.4)
plt.subplot(336)
plt.plot( 'x','z', data=df, linestyle='none', marker='o', color="orange", alpha=0.3)
plt.subplot(337)
plt.plot( 'x','z', data=df, linestyle='none', marker='D', color="cyan", alpha=0.3)
plt.subplot(338)
plt.plot( 'x','z', data=df, marker='x', color="grey", alpha=0.3)
plt.subplot(339)
plt.plot( 'x','z', data=df, marker='x', color="grey", alpha=0.3)
plt.show()

# %%
#free dataset I've used for another project
df = pd.read_csv("mtcars.csv")
x = df.loc[:, ['mpg']]
df['mpg_z'] = (x - x.mean())/x.std()

# Conditional function for plotting + OR - 
df['colors'] = ['red' if x < 0 else 'green' for x in df['mpg_z']]
df.sort_values('mpg_z', inplace=True)
df.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df.index, xmin=0, xmax=df.mpg_z, color=df.colors, alpha=0.4, linewidth=5)

#Plot styling 
plt.gca().set(ylabel='Model', xlabel='Mileage by standard deviation')
plt.yticks(df.index, df.cars, fontsize=12)
plt.title('Millage my STD', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)

# %%
#loading dataset. 
df = pd.read_csv("mtcars.csv")

#Configuring data for heatmap 
plt.figure(figsize=(12,10), dpi= 70)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='Blues', 
            center=0, annot=True)

# Configuring legend/title/fonts
plt.title('Correlation of columns in dataset', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#NOTE: Compiling this in Jupyter notebook cuts off 1/2 of the top and bottom row of this visualization
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]), <a list of 12 Text yticklabel objects>)
